# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2021/01
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM: SysArq
#
# ##### Semester: 2021/01
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Joao Gabriel Rossi
# - Paulo Vitor Coelho
# - Joao Matheus
# - Ivan Diniz Dobbin
# - Gabriel Marcolino
# - Carlos Eduardo Roriz
# - Lorenzo Santos

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json
from glob import glob
import os

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Datetime
from datetime import datetime

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %% [markdown]
# ##### Path to the folder with all your jsons

# %%
jsons = glob('../analytics-raw-data/*.json') # add the path here

# %%
def read_json(json_path):
    
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
        
    return json_obj

def create_base_component_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        base_component = read_json(i)

        base_component_data = base_component['baseComponent']['measures']

        base_component_df = pd.DataFrame(base_component_data)

        base_component_df['filename'] = os.path.basename(i)

        df = df.append(base_component_df, ignore_index=True)
        
    aux_df = df['filename'].str.split(r"fga-eps-mds-2021.1-(.*?)-*-(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df

# %% [markdown]
# #### Create base component dataframe

# %%
base_component_df = create_base_component_df(jsons)

# %%
base_component_df.head(10)
# Out:
#                       metric value bestValue  \
# 88                complexity     5       NaN
# 89  duplicated_lines_density   0.0      True
# 90                 functions     5       NaN
# 91                     ncloc    50       NaN
# 92        reliability_rating   1.0      True
# 93           security_rating   1.0      True
# 94     comment_lines_density   0.0     False
# 95                     files    12       NaN
# 72  duplicated_lines_density   0.0      True
# 73                 functions   127       NaN
#
#                                              filename     repository  \
# 88  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 89  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 90  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 91  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 92  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 93  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 94  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 95  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...  MULTILIND_APP
# 72  fga-eps-mds-2021_1-MULTILIND_APP-2021-11-03-22...  MULTILIND_APP
# 73  fga-eps-mds-2021_1-MULTILIND_APP-2021-11-03-22...  MULTILIND_APP
#
#              version
# 88  2021-09-14-03:28
# 89  2021-09-14-03:28
# 90  2021-09-14-03:28
# 91  2021-09-14-03:28
# 92  2021-09-14-03:28
# 93  2021-09-14-03:28
# 94  2021-09-14-03:28
# 95  2021-09-14-03:28
# 72  2021-11-03-22:59
# 73  2021-11-03-22:59

# %% [markdown]
# #### Create dataframe per file

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 12

# %%
def metric_per_file(json):
    
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

def generate_file_dataframe_per_release(metric_list, json, language_extension):
    
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns, dtype=object)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

def create_file_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        file_component = read_json(i)
        
        file_component_data = metric_per_file(file_component)
        
        file_component_df_py = generate_file_dataframe_per_release(metric_list, file_component_data, language_extension = 'py')
        file_component_df_js = generate_file_dataframe_per_release(metric_list, file_component_data, language_extension = 'js')

        file_component_df_py['filename'] = os.path.basename(i)
        file_component_df_js['filename'] = os.path.basename(i)

        df = df.append(file_component_df_js, ignore_index=True)
        df = df.append(file_component_df_py, ignore_index=True)
          
    aux_df = df['filename'].str.split(r"/.*.json/", expand=True)
    print(len(aux_df))
    df['repository'] = aux_df[3]
    
    df['version'] = aux_df[4]
    
    df = df.sort_values(by=['repository', 'version'])
    print(df)   
    return df

# %%
file_component_df = create_file_df(jsons)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/venv/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_22059/2471823116.py in <module>
# ----> 1 file_component_df = create_file_df(jsons)
#
# /tmp/ipykernel_22059/954758200.py in create_file_df(json_list)
#      47
#      48     aux_df = df['filename'].str.split(r"/.*.json/", expand=True)
# ---> 49     print(aux_df[3])
#      50     df['repository'] = aux_df[3]
#      51
#
# ~/venv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/venv/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 3

# %%
file_component_df.head(10)
# Out:
#                                      path functions complexity  \
# 517                                App.js         1          1
# 518                       babel.config.js         1          1
# 519                  src/screens/index.js         0          0
# 520  src/screens/SettingsScreen/index.jsx         1          1
# 521       src/screens/MapScreen/index.jsx         1          1
# 522      src/screens/HomeScreen/index.jsx         1          1
# 523  src/screens/SettingsScreen/styles.js         0          0
# 524       src/screens/MapScreen/styles.js         0          0
# 525      src/screens/HomeScreen/styles.js         0          0
# 404                   src/services/api.js         0          0
#
#     comment_lines_density duplicated_lines_density coverage ncloc  \
# 517                   0.0                      0.0      NaN     5
# 518                   0.0                      0.0      NaN    27
# 519                   0.0                      0.0      NaN     3
# 520                   0.0                      0.0      NaN     5
# 521                   0.0                      0.0      NaN     5
# 522                   0.0                      0.0      NaN     5
# 523                   NaN                      0.0      NaN     0
# 524                   NaN                      0.0      NaN     0
# 525                   NaN                      0.0      NaN     0
# 404                   0.0                      0.0      NaN     9
#
#     security_rating tests test_success_density test_execution_time  \
# 517             1.0   NaN                100.0                 NaN
# 518             1.0   NaN                100.0                 NaN
# 519             1.0   NaN                100.0                 NaN
# 520             1.0   NaN                100.0                 NaN
# 521             1.0   NaN                100.0                 NaN
# 522             1.0   NaN                100.0                 NaN
# 523             1.0   NaN                100.0                 NaN
# 524             1.0   NaN                100.0                 NaN
# 525             1.0   NaN                100.0                 NaN
# 404             1.0   NaN                100.0                 NaN
#
#     reliability_rating                                           filename  \
# 517                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 518                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 519                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 520                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 521                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 522                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 523                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 524                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 525                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-09-14-03...
# 404                1.0  fga-eps-mds-2021_1-MULTILIND_APP-2021-11-03-22...
#
#         repository           version
# 517  MULTILIND_APP  2021-09-14-03:28
# 518  MULTILIND_APP  2021-09-14-03:28
# 519  MULTILIND_APP  2021-09-14-03:28
# 520  MULTILIND_APP  2021-09-14-03:28
# 521  MULTILIND_APP  2021-09-14-03:28
# 522  MULTILIND_APP  2021-09-14-03:28
# 523  MULTILIND_APP  2021-09-14-03:28
# 524  MULTILIND_APP  2021-09-14-03:28
# 525  MULTILIND_APP  2021-09-14-03:28
# 404  MULTILIND_APP  2021-11-03-22:59

# %% [markdown]
# #### Create dataframe per repository

# %%
archives_df = file_component_df[file_component_df['repository'] == 'Archives']
profile_df = file_component_df[file_component_df['repository'] == 'Profile']
frontend_df = file_component_df[file_component_df['repository'] == 'Frontend']
print(len(archives_df.index))
# Out:
# 0

# %% [markdown]
# ### Metric calculations

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df)
    
    return duplication

# %% [markdown]
# ### Calculate m1, m2 and m3 for each repository

# %%
def create_metrics_df(df):
    
    version_vec = df['version'].unique()
    
    m1_list = []
    m2_list = []
    m3_list = []
    repository_list = []
    version_list = []
    
    metrics_df = pd.DataFrame()
    
    for version in version_vec:

        version_df = df[df['version'] == version]

        m1_list.append(m1(version_df))
        m2_list.append(m2(version_df))
        m3_list.append(m3(version_df))
        repository_list.append(version_df['repository'].iloc[0])
        version_list.append(version)
        
    metrics_df = pd.DataFrame({'m1': m1_list,
                               'm2': m2_list,
                               'm3': m3_list,
                               'repository': repository_list, 
                               'version': version_list})
        
    return metrics_df

# %%
archives_metrics = create_metrics_df(archives_df)
print(archives_metrics)
profile_metrics = create_metrics_df(profile_df)
frontend_metrics = create_metrics_df(frontend_df)
# Out:
# Empty DataFrame
# Columns: [m1, m2, m3, repository, version]
# Index: []

# %% [markdown]
# ### Data visualization
#
# - You must do this for each of your repositories

# %% [markdown]
# # ARCHIVES

# %% [markdown]
# ## M1

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(archives_metrics['m1'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M2

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(archives_metrics['m2'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M3

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(archives_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## TOTAL

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(archives_metrics['m1'], linewidth=3, marker='o', markersize=10)
plt.plot(archives_metrics['m2'], linewidth=3, marker='o', markersize=10)
plt.plot(archives_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# # Profile

# %% [markdown]
# ## M1

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(profile_metrics['m1'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M2

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(profile_metrics['m2'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M3

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(profile_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## TOTAL

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(profile_metrics['m1'], linewidth=3, marker='o', markersize=10)
plt.plot(profile_metrics['m2'], linewidth=3, marker='o', markersize=10)
plt.plot(profile_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# # Frontend

# %% [markdown]
# ## M1

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(frontend_metrics['m1'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M2

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(frontend_metrics['m2'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## M3

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(frontend_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## TOTAL

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(frontend_metrics['m1'], linewidth=3, marker='o', markersize=10)
plt.plot(frontend_metrics['m2'], linewidth=3, marker='o', markersize=10)
plt.plot(frontend_metrics['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ### Sub characteristic aggregation
#
# - You must do this for each of your repositories

# %%
psc1 = 1
pc = 1
pm1 = 0.33
pm2 = 0.33
pm3 = 0.33

archives_metrics['code_quality'] = ((archives_metrics['m1']*pm1)+(archives_metrics['m2']*pm2)+(archives_metrics['m3']*pm3))*psc1
profile_metrics['code_quality'] = ((profile_metrics['m1']*pm1)+(profile_metrics['m2']*pm2)+(profile_metrics['m3']*pm3))*psc1
frontend_metrics['code_quality'] = ((frontend_metrics['m1']*pm1)+(frontend_metrics['m2']*pm2)+(frontend_metrics['m3']*pm3))*psc1

# %% [markdown]
# ## Code Quality

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(archives_metrics['code_quality'], linewidth=3, marker='o', markersize=10)
plt.plot(profile_metrics['code_quality'], linewidth=3, marker='o', markersize=10)
plt.plot(frontend_metrics['code_quality'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## All Metrics

# %%
metrics_df = pd.concat([archives_metrics, profile_metrics, frontend_metrics], ignore_index=True)

metrics_df['maintainability'] = metrics_df['code_quality'] * pc
metrics_df['total'] = metrics_df['maintainability'] * pc

# %%
metrics_df
# Out:
#          m1        m2        m3 repository           version  code_quality  \
# 0  0.133333  0.200000  1.000000   Archives  03-10-2021-15-47      0.440000
# 1  0.142857  0.214286  1.000000   Archives  13-09-2021-15-00      0.447857
# 2  0.142857  0.214286  1.000000    Profile  03-10-2021-15-48      0.447857
# 3  0.142857  0.214286  1.000000    Profile  13-09-2021-14-00      0.447857
# 4  0.933333  0.022222  0.977778   Frontend  03-10-2021-15-49      0.638000
# 5  0.666667  0.166667  1.000000   Frontend  13-09-2021-20-00      0.605000
#
#    maintainability     total
# 0         0.440000  0.440000
# 1         0.447857  0.447857
# 2         0.447857  0.447857
# 3         0.447857  0.447857
# 4         0.638000  0.638000
# 5         0.605000  0.605000

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(metrics_df['maintainability'], linewidth=3, marker='o', markersize=5)

plt.ylim(.4,.7)
# Out:
# (0.4, 0.7)

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(metrics_df['total'], linewidth=3, marker='o', markersize=5)

# plt.ylim(.4,.7)

# %% [markdown]
# # Metrics to file

# %%
metrics_df.to_excel('data/metrics_df.xlsx', index = False)

# %%
now = datetime.now()
now_str = now.strftime("%d-%m-%Y-%H-%M")

metrics_df.to_csv('./data/fga-eps-mds-fga-eps-mds-2021.1-Multilind-qualidade-total-produto-{}.csv'.format(now_str), index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22059/2250439445.py in <module>
#       2 now_str = now.strftime("%d-%m-%Y-%H-%M")
#       3
# ----> 4 metrics_df.to_csv('./data/fga-eps-mds-fga-eps-mds-2021.1-Multilind-qualidade-total-produto-{}.csv'.format(now_str), index = False)
#
# NameError: name 'metrics_df' is not defined
